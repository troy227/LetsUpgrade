# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Tushar\Desktop\Day-7\Assignment\general_data.csv")

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
le.fit(df.Attrition)
# Out:
# LabelEncoder()

# %%
df['Attrition']=le.transform(df.Attrition)

# %%
df.head(2)
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0  Female  ...                 1.0      Y                11              8
# 1  Female  ...                 0.0      Y                23              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df['BusinessTravel']=le.fit_transform(df.BusinessTravel)

# %%
df['Department']=le.fit_transform(df.Department)

# %%
df['DistanceFromHome']=le.fit_transform(df.DistanceFromHome)

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               2           2                 5          2
# 1   31          1               1           1                 9          1
# 2   32          0               1           1                16          4
# 3   38          0               0           1                 1          5
# 4   32          0               2           1                 9          1
#
#   EducationField  EmployeeCount  EmployeeID  Gender  ...  NumCompaniesWorked  \
# 0  Life Sciences              1           1  Female  ...                 1.0
# 1  Life Sciences              1           2  Female  ...                 0.0
# 2          Other              1           3    Male  ...                 1.0
# 3  Life Sciences              1           4    Male  ...                 3.0
# 4        Medical              1           5    Male  ...                 4.0
#
# ...

# %%
df['EducationField']=le.fit_transform(df.EducationField)

# %%
df['Gender']=le.fit_transform(df.Gender)

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               2           2                 5          2
# 1   31          1               1           1                 9          1
# 2   32          0               1           1                16          4
# 3   38          0               0           1                 1          5
# 4   32          0               2           1                 9          1
#
#    EducationField  EmployeeCount  EmployeeID  Gender  ...  NumCompaniesWorked  \
# 0               5              1           1       0  ...                 1.0
# 1               9              1           2       0  ...                 0.0
# 2              16              1           3       1  ...                 1.0
# 3               1              1           4       1  ...                 3.0
# 4               9              1           5       1  ...                 4.0
#
# ...

# %%
from scipy.stats import pearsonr

# %%
stats,p=pearsonr(df.Age,df.Attrition)
print("Correlation of Age and Attrition is-",stats)
# Out:
# Correlation of Age and Attrition is- -0.1592050068657796

# %%
stats,p=pearsonr(df.BusinessTravel,df.Attrition)
print("Correlation of Business Travel and Attrition is-",stats)
# Out:
# Correlation of Business Travel and Attrition is- 7.37769460222686e-05

# %%
stats,p=pearsonr(df.Department,df.Attrition)
print("Correlation of Department and Attrition is-",stats)
# Out:
# Correlation of Department and Attrition is- -0.04820581991834006

# %%
stats,p=pearsonr(df.DistanceFromHome,df.Attrition)
print("Correlation of Distance from Home and Attrition is-",stats)
# Out:
# Correlation of Distance from Home and Attrition is- -0.009730141010179659

# %%
stats,p=pearsonr(df.Gender,df.Attrition)
print("Correlation of Gender and Attrition is-",stats)
# Out:
# Correlation of Gender and Attrition is- 0.018125078877010262

# %%
stats,p=pearsonr(df.Education,df.Attrition)
print("Correlation of Education and Attrition is-",stats)
# Out:
# Correlation of Education and Attrition is- -0.015111167710968744

# %%
stats,p=pearsonr(df.EducationField,df.Attrition)
print("Correlation of Education Field and Attrition is-",stats)
# Out:
# Correlation of Education Field and Attrition is- -0.009730141010179659

# %%
stats,p=pearsonr(df.PercentSalaryHike,df.Attrition)
print("Correlation of Salary Hike and Attrition is-",stats)
# Out:
# Correlation of Salary Hike and Attrition is- 0.032532594891053514

# %%
stats,p=pearsonr(df.YearsAtCompany,df.Attrition)
print("Correlation of Years at Company and Attrition is-",stats)
# Out:
# Correlation of Years at Company and Attrition is- -0.13439221398997717

# %% [markdown]
# ## Correlation Matrix

# %%
df.corr()
# Out:
#                               Age  Attrition  BusinessTravel  Department  \
# Age                      1.000000  -0.159205        0.024751   -0.010846
# Attrition               -0.159205   1.000000        0.000074   -0.048206
# BusinessTravel           0.024751   0.000074        1.000000   -0.010982
# Department              -0.010846  -0.048206       -0.010982    1.000000
# DistanceFromHome         0.006963  -0.009730        0.024616    0.012134
# Education               -0.035706  -0.015111        0.002755   -0.004597
# EducationField           0.006963  -0.009730        0.024616    0.012134
# EmployeeCount                 NaN        NaN             NaN         NaN
# EmployeeID               0.008649  -0.004729       -0.002590   -0.003455
# Gender                  -0.039352   0.018125       -0.039243    0.003158
# JobLevel                -0.002884  -0.010290        0.046111    0.002923
# MonthlyIncome           -0.044314  -0.031176       -0.037597   -0.032237
# ...

# %% [markdown]
# ## HIGHEST AND LOWEST CORRELATIONS

# %%
df.corr().unstack().sort_values().drop_duplicates()
# Out:
# Attrition                TotalWorkingYears         -0.170338
# Age                      Attrition                 -0.159205
# Attrition                YearsWithCurrManager      -0.156199
# YearsAtCompany           Attrition                 -0.134392
# NumCompaniesWorked       YearsAtCompany            -0.117959
# YearsWithCurrManager     NumCompaniesWorked        -0.109667
# TrainingTimesLastYear    StockOptionLevel          -0.069902
# Gender                   NumCompaniesWorked        -0.066924
# YearsAtCompany           JobLevel                  -0.064219
# JobLevel                 YearsSinceLastPromotion   -0.060811
#                          YearsWithCurrManager      -0.055251
# Attrition                TrainingTimesLastYear     -0.049431
# Department               Attrition                 -0.048206
# Age                      MonthlyIncome             -0.044314
# EducationField           Gender                    -0.044173
# ...
